# %% [markdown]
# # Sample Notebook that creates a classification model from a Pandas DataFrame
#
# ## Start by importing pixiedust and tensorflow

# %%
import pixiedust
import tensorflow as tf

# %% [markdown]
# ## Browse the PixieDust built-in DataSets

# %%
pixiedust.sampleData()
# Out:
# <table class="table table-hover pd_save" style="font-size:small">
#   <thead>
#     <tr>
#       <th align="center" valign="middle">Id</th>
#       <th>Name</th>
#       <th>Topic</th>
#       <th>Publisher</th>
#     </tr>
#   </thead>
#   <tbody>
#
#
#     <tr>
#         <td>1</td>
#         <td>Car performance data</td>
#         <td>Transportation</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>2</td>
#         <td>Sample retail sales transactions, January 2009</td>
#         <td>Economy & Business</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>3</td>
#         <td>Total population by country</td>
#         <td>Society</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>4</td>
#         <td>GoSales Transactions for Naive Bayes Model</td>
#         <td>Leisure</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>5</td>
#         <td>Election results by County</td>
#         <td>Society</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>6</td>
#         <td>Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018</td>
#         <td>Economy & Business</td>
#         <td>Redfin.com</td>
#     </tr>
#
#
#
#     <tr>
#         <td>7</td>
#         <td>Boston Crime data, 2-week sample</td>
#         <td>Society</td>
#         <td>City of Boston</td>
#     </tr>
#
#
#   </tbody>
# </table>

# %% [markdown]
# ## Load the Boston Crime dataset

# %%
import pixiedust
crimes = pixiedust.sampleData(7)
# Out:
# Downloading 'Boston Crime data, 2-week sample' from https://raw.githubusercontent.com/ibm-watson-data-lab/open-data/master/crime/boston_crime_sample.csv
# Downloaded 2986857 bytes
# Creating pandas DataFrame for 'Boston Crime data, 2-week sample'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'Boston Crime data, 2-week sample'

# %% [markdown]
# ## Do some exploration using the "display()" API

# %%
display(crimes)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFiguree96ec03b" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-e96ec03b")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"54efb386-e115-4f7c-b5da-305c6c6e4d90":{"roots":{"references":[{"attributes":{},"id":"b84dbfce-a3c2-42cd-a335-dec3d83414af","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["l","counts","x"],"data":{"counts":[1670,11887],"l":["pd_count","pd_count"],"x":[["0","pd_count"],["1","pd_count"]]}},"id":"f492efa6-8f3e-4af7-8df7-edd8e36d0392","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"6d5b7c75-f6de-4137-8aa3-c742131d2623","type":"ToolbarBox"},{"id":"41fe37b2-ece4-45bb-84da-02e56986c883","type":"Column"}]},"id":"47c3357a-dfa8-40aa-a966-6c6913e68a91","type":"Column"},{"attributes":{"fill_color":{"field":"x","transform":{"id":"3a55baff-37aa-4d29-8dc8-736cd623b2c2","type":"CategoricalColorMapper"}},"line_color":{"field":"x","transform":{"id":"3a55baff-37aa-4d29-8dc8-736cd623b2c2","type":"CategoricalColorMapper"}},"top":{"field":"counts"},"width":{"value":0.925},"x":{"field":"x"}},"id":"95a234e4-b954-406f-ab73-470ad257a011","type":"VBar"},{"attributes":{},"id":"1d21e155-3cb3-49c7-9aa4-cf7bc791ff57","type":"LinearScale"},{"attributes":{},"id":"3ad5530c-24d8-4a5b-8780-bbfd6aaeeba3","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"counts"},"width":{"value":0.925},"x":{"field":"x"}},"id":"edd8d664-fa9c-4ee1-951a-be2fb4465477","type":"VBar"},{"attributes":{},"id":"5374eb22-a649-4dd7-add9-4659e07b8733","type":"BasicTicker"},{"attributes":{},"id":"3aa5204f-7fd1-4d3c-acc7-3f29ea8e282a","type":"PanTool"},{"attributes":{},"id":"7b5f1535-7f19-412b-839c-d0c400908f33","type":"WheelZoomTool"},{"attributes":{"axis_label":"pd_count","formatter":{"id":"13576e70-e1e3-4495-90d8-3498858de04f","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"3c5bf8f9-1b1c-4a79-bb6b-5e016fe71d48","subtype":"Figure","type":"Plot"},"ticker":{"id":"5374eb22-a649-4dd7-add9-4659e07b8733","type":"BasicTicker"}},"id":"2b48ee76-a604-4fb6-8ddc-17b21f5d90ce","type":"LinearAxis"},{"attributes":{"source":{"id":"f492efa6-8f3e-4af7-8df7-edd8e36d0392","type":"ColumnDataSource"}},"id":"b8eee87c-4cfc-48f4-a75b-63e02e0d3b9f","type":"CDSView"},{"attributes":{},"id":"1c55aae1-1915-46aa-b3b0-d9aa5c4cfee5","type":"CategoricalScale"},{"attributes":{"callback":null,"factors":[["0","pd_count"],["1","pd_count"]],"range_padding":0.1},"id":"62185391-cc8b-4562-9bc4-7c68acb42bc3","type":"FactorRange"},{"attributes":{"tools":[{"id":"3aa5204f-7fd1-4d3c-acc7-3f29ea8e282a","type":"PanTool"},{"id":"7b5f1535-7f19-412b-839c-d0c400908f33","type":"WheelZoomTool"},{"id":"bbe994ef-b6b9-43cd-a701-2e063fdcd9d1","type":"BoxZoomTool"},{"id":"07539379-1c10-444c-b86b-60e299315689","type":"SaveTool"},{"id":"b84dbfce-a3c2-42cd-a335-dec3d83414af","type":"ResetTool"},{"id":"0cd48e5d-bedc-4238-bfcd-80b2848eac52","type":"HelpTool"}]},"id":"247f6680-e751-4b09-8356-20e2b4305add","type":"ProxyToolbar"},{"attributes":{"label":{"field":"l"},"renderers":[{"id":"918fd35c-fb6c-4bfb-be2d-6526e29d5579","type":"GlyphRenderer"}]},"id":"26809984-8a40-4ba8-9483-4dd6f0a53d31","type":"LegendItem"},{"attributes":{"dimension":1,"plot":{"id":"3c5bf8f9-1b1c-4a79-bb6b-5e016fe71d48","subtype":"Figure","type":"Plot"},"ticker":{"id":"5374eb22-a649-4dd7-add9-4659e07b8733","type":"BasicTicker"}},"id":"f290b8cb-3f84-4d40-b01c-3242f6c31fec","type":"Grid"},{"attributes":{"callback":null,"start":0},"id":"c916cba3-d050-41ac-8656-5acaba2287c8","type":"DataRange1d"},{"attributes":{"toolbar":{"id":"247f6680-e751-4b09-8356-20e2b4305add","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"6d5b7c75-f6de-4137-8aa3-c742131d2623","type":"ToolbarBox"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"3c5bf8f9-1b1c-4a79-bb6b-5e016fe71d48","subtype":"Figure","type":"Plot"},"ticker":{"id":"3ad5530c-24d8-4a5b-8780-bbfd6aaeeba3","type":"CategoricalTicker"}},"id":"cf79c14e-2692-48ec-a71c-7a130d9c3271","type":"Grid"},{"attributes":{"bottom ...

# %% [markdown]
# ## Implement the training method using tensorflow DNNClassifier

# %%
import tensorflow as tf

def do_training(train, train_labels, test, test_labels, num_classes):
    #set TensorFlow logging level to INFO
    tf.logging.set_verbosity(tf.logging.INFO)

    # Build 2 hidden layer DNN with 10, 10 units respectively.
    classifier = tf.estimator.DNNClassifier(
        # Compute feature_columns from dataframe keys using list comprehension
        feature_columns =
            [tf.feature_column.numeric_column(key=key) for key in train.keys()],
        hidden_units=[10, 10],
        n_classes=num_classes)

    # Train the Model
    classifier.train(
        input_fn=lambda:train_input_fn(train, train_labels,100),
        steps=1000
    )

    # Evaluate the model
    eval_result = classifier.evaluate(
        input_fn=lambda:eval_input_fn(test, test_labels,100)
    )

    return (classifier, eval_result)

def input_fn(features, labels, batch_size, train):
    # Convert the inputs to a Dataset and shuffle.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels)).shuffle(1000)
    if train:
        #repeat only for training
        dataset = dataset.repeat()
    # Return the dataset in batch
    return dataset.batch(batch_size)

def train_input_fn(features, labels, batch_size):
    return input_fn(features, labels, batch_size, train=True)

def eval_input_fn(features, labels, batch_size):
    return input_fn(features, labels, batch_size, train=False)

# %% [markdown]
# ## Implement the PixieApp for creating the classification model

# %%
from pixiedust.display.app import *

@PixieApp
class SimpleClassificationDNN():
    @route()
    def main_screen(self):
        return """

<h1 style="margin:40px">
    <center>The classificiation model will be trained on all the numeric columns of the dataset</center>
</h1>

<style>
    div.outer-wrapper {
        display: table;width:100%;height:300px;
    }
    div.inner-wrapper {
        display: table-cell;vertical-align: middle;height: 100%;width: 100%;
    }
</style>
<div class="outer-wrapper">
    <div class="inner-wrapper">
        <div class="col-sm-3"></div>
        <div class="input-group col-sm-6">
          <select id="cols{{prefix}}" style="width:100%;height:30px" pd_options="predictor=$val(cols{{prefix}})">
              <option value="0">Select a predictor column</option>
              {%for col in this.pixieapp_entity.columns.values.tolist()%}
              <option value="{{col}}">{{col}}</option>
              {%endfor%}
          </select>
        </div>
    </div>
</div>     
        """
    
    @route(predictor="*")
    @templateArgs
    def prepare_training(self, predictor):
        #select only numerical columns
        self.dataset = self.pixieapp_entity.dropna(axis=1).select_dtypes(
            include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
        )
        #Compute the number of classed by counting the groups
        self.num_classes = self.dataset.groupby(predictor).size().shape[0]
        #Create the train and test feature and labels
        self.train_x=self.dataset.sample(frac=0.8)
        self.full_train = self.train_x.copy()
        self.train_y = self.train_x.pop(predictor)
        self.test_x=self.dataset.drop(self.train_x.index)
        self.full_test = self.test_x.copy()
        self.test_y=self.test_x.pop(predictor)
        
        bar_chart_options = {
          "rowCount": "100",
          "keyFields": predictor,
          "handlerId": "barChart",
          "noChartCache": "true"
        }
        
        return """
<div class="container" style="margin-top:20px">
    <div class="row">
        <div class="col-sm-5">
            <h3><center>Train set class distribution</center></h3>
            <div pd_entity="full_train" pd_render_onload>
                <pd_options>{{bar_chart_options|tojson}}</pd_options>
            </div>
        </div>
        <div class="col-sm-5">
            <h3><center>Test set class distribution</center></h3>
            <div pd_entity="full_test" pd_render_onload>
                <pd_options>{{bar_chart_options|tojson}}</pd_options>
            </div>
        </div>
    </div>
</div>

<div style="text-align:center">
    <button class="btn btn-default" type="submit" pd_options="do_training=true">
        Start Training
    </button>
</div>
"""
    
    @route(do_training="*")
    @captureOutput
    def do_training_screen(self):
        self.classifier, self.eval_results = \
            do_training(self.train_x, self.train_y, self.test_x, self.test_y, self.num_classes)
        return """
<h2>Training completed successfully</h2>
<table>
    <thead>
        <th>Metric</th>
        <th>Value</th>
    </thead>
    <tbody>
{%for key,value in this.eval_results.items()%}
<tr>
    <td>{{key}}</td>
    <td>{{value}}</td>
</tr>
{%endfor%}
    </tbody>
</table>
        """
    
app = SimpleClassificationDNN()
app.run(crimes)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
